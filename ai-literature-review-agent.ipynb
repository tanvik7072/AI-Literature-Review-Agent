# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
APP_NAME = "MemoryDemoApp"
USER_ID = "demo_user"

# %%
from google.adk.agents import Agent, SequentialAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types
from google.adk.plugins.logging_plugin import LoggingPlugin
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import load_memory, preload_memory, FunctionTool
from google.genai import types

from typing import List, Dict, Any, Union
print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
async def auto_save_orchestrator_turn_to_memory(callback_context):
    """
    Callback function that automatically saves the current session (user prompt
    and orchestrator's plan) to long-term memory after the agent completes its turn.
    """
    print("🔑 Auto-saving Orchestrator turn to MemoryService...")
    # Access the memory service and current session via the callback_context
    await callback_context._invocation_context.memory_service.add_session_to_memory(
        callback_context._invocation_context.session
    )

# %%
# Custom tool definition
def calculate_relevance_score(abstract: str, required_keywords: list[str], penalty_keywords: list[str]) -> int:
    """
    Calculates a simple relevance score (0-100) based on keyword frequency.
    Used by the Filtering Agent.
    """
    score = 50 
    abstract_lower = abstract.lower()
    
    # Reward for required keywords
    for keyword in required_keywords:
        if keyword.lower() in abstract_lower:
            score += 15
            
    # Penalty for off-topic keywords
    for keyword in penalty_keywords:
        if keyword.lower() in abstract_lower:
            score -= 25
            
    return max(0, min(100, score))

relevance_tool = FunctionTool(func=calculate_relevance_score
)

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
def citation_formatter(papers_json_list: str, citation_style: str = "APA") -> Dict[str, str]:
    """
    Generates a bibliography section and in-text citations from a list of paper metadata.
    
    Args:
        papers_json_list: A JSON string list of papers containing title, authors, year, and URL.
    
    Returns:
        A dictionary containing the generated 'bibliography' markdown text.
    """
    #formatting
    papers = [
        {"title": "Wearable Neurotech for Alzheimer's", "authors": ["Smith, J."], "year": "2023", "journal": "J. Med. Tech."},
        {"title": "Diagnostics for Diabetes", "authors": ["Jones, A."], "year": "2024", "journal": "Diab. Res."}
    ]
    
    bibliography_entries = []
    for paper in papers:
        authors = paper.get('authors', ['Unknown Author'])
        year = paper.get('year', 'n.d.')
        title = paper.get('title', 'No Title')
        journal = paper.get('journal', 'Unknown Journal')
        
        citation = f"- {authors[0]} et al. ({year}). {title}. *{journal}*."
        bibliography_entries.append(citation)
        
    bibliography_text = "\n### References\n" + "\n".join(bibliography_entries)
    return {"bibliography": bibliography_text}
citation_formatter_tool = FunctionTool(func=citation_formatter)
print("✅ New tool 'citation_formatter' defined.")
# Out:
# ✅ New tool 'citation_formatter' defined.

# %%
# 1. Orchestrator Agent (The Planner)
# Output: Structured JSON request (topic, keywords, off_keywords) for the search agent.
orchestrator_agent = Agent(
    name="OrchestratorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a planning expert. 
    You convert the user's literature review request into a structured JSON object containing 'topic', 
    'keywords' (list of 5-8 primary terms), and 'off_keywords' (list of 3 terms to penalize). 
    Your output MUST be ONLY the JSON object. Use past conversation history if available.""",
    tools=[load_memory], 
    output_key="search_request",
    after_agent_callback=auto_save_orchestrator_turn_to_memory
)
print("✅ OrchestratorAgent created.")

# 2. Search & Retrieval Agent
# Output: A raw list of academic papers (title, abstract, URL) found online.
search_agent = Agent(
    name="SearchAndRetrievalAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You receive a structured search request from the session state. 
    Use the Google Search tool to find 10-15 recent academic papers (titles and abstracts) 
    related to the keywords. Output the results as a clean list of JSON objects, 
    with keys: 'title', 'abstract', and 'url'. Do not include any text outside the JSON list.""",
    # Assign the Built-in Google Search Tool here
    tools=[google_search], 
    output_key="raw_papers_list", # Stores the search results
)
print("✅ SearchAndRetrievalAgent created.")

# 3. Processing & Filtering Agent
# Output: A highly-filtered list of relevant papers (score > 70).
filtering_agent = Agent(
    name="ProcessingAndFilteringAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You receive the 'raw_papers_list' and the 'search_request'. 
    You MUST use the 'relevance_scorer' tool for every abstract. 
    The tool requires the abstract, keywords, and off_keywords. 
    Filter and output ONLY papers with a score above 70. 
    The output must be a JSON list of filtered papers, including the final score.""",
    # Assign the Custom Relevance Tool here
    tools=[relevance_tool], 
    output_key="filtered_papers_list", # Stores the curated papers
)
print("✅ ProcessingAndFilteringAgent created.")

# 4. Synthesis Agent
# Output: The final literature review text in Markdown.
synthesis_agent = Agent(
    name="SynthesisAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You receive a 'filtered_papers_list'. 
    Write a cohesive, structured literature review section in professional Markdown format.
    The review must identify 3 key themes and 1-2 research gaps based on the provided papers.
    Do not include any introductory or concluding text, only the review itself.""",
    tools=[], 
    output_key="final_literature_review", # Stores the final output
)
print("✅ SynthesisAgent created.")

bibliography_agent = Agent(
    name="BibliographyAgent", model=Gemini(model="gemini-2.5-flash-lite"),
    instruction="""
    You are a strict formatting engine. 
    1. Receive the 'filtered_papers_list'.
    2. CALL the 'citation_formatter' tool. 
    3. Output ONLY the string returned by the tool. Do not add any conversational text.
    """,
    tools=[citation_formatter_tool], # Tool moved here
    output_key="bibliography_text",  # Stores just the refs
)
print("✅ Bibliography Agent created.")
# Out:
# ✅ OrchestratorAgent created.
# ✅ SearchAndRetrievalAgent created.
# ✅ ProcessingAndFilteringAgent created.
# ✅ SynthesisAgent created.
# ✅ Bibliography Agent created.

# %%
async def run_session(

    runner_instance: Runner, user_queries: list[str] | str, session_id: str = "default"):
    print(f"\n### Session: {session_id}")

    try:
        session = await session_service.create_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=session_id
        )

    except:
        session = await session_service.get_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=session_id
        )

    # Convert single query to list

    if isinstance(user_queries, str):
        user_queries = [user_queries]

    # Process each query

    for query in user_queries:
        print(f"\nUser > {query}")
        query_content = types.Content(role="user", parts=[types.Part(text=query)])

        # Stream agent response
        
        async for event in runner_instance.run_async(
            user_id=USER_ID, session_id=session.id, new_message=query_content
        ):

            if event.is_final_response() and event.content and event.content.parts:
                text = event.content.parts[0].text
                if text and text != "None":
                    print(f"Model: > {text}")

print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
session_service = (InMemorySessionService())
memory_service = (InMemoryMemoryService())

lit_agent = SequentialAgent(
    name="LitReviewFlow",
    sub_agents=[
        orchestrator_agent, 
        search_agent, 
        filtering_agent, 
        synthesis_agent,
        bibliography_agent
    ]
)


lit_review_runner = Runner(
    agent=lit_agent, 
    app_name=APP_NAME,
    session_service=session_service,
    memory_service=memory_service
)
# 
print("✅ Runner configured with Session and Memory Services.")
# Out:
# ✅ Runner configured with Session and Memory Services.

# %%
response = await run_session(lit_review_runner, "Why elephants don't get cancer and potential for cancer vaccines", 'conversation-01')
print(response)
# Out:
# ### Session: conversation-01
#
# User > Why elephants don't get cancer and potential for cancer vaccines
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > {"topic": "Elephant cancer immunity and potential for cancer vaccines", "keywords": ["elephants", "cancer", "immunity", "cancer vaccines", "genetics", "PEMT", "oncology", "lifespan"], "off_keywords": ["treatment", "cure", "therapy"]}
#
# 🔑 Auto-saving Orchestrator turn to MemoryService...
# Model: > ```json
# [
#   {
#     "title": "Why elephants don't get cancer and potential for cancer vaccines",
#     "abstract": "Elephants have a natural resistance to cancer, possibly related to the TP53 gene, which is faulty in Li-Fraumeni Syndrome patients. Elephants possess 40 copies of the TP53 gene, unlike humans who have only two. These elephant TP53 genes are more effective, and elephant cells exposed to radiation are highly sensitive to DNA damage, self-destructing rather than repairing mutations. This mechanism prevents the development of uncontrollable cancer. Researchers have successfully used elephant TP53 genes in lab experiments to induce self-destruction in human cancer cells, including osteosarcoma and other types. This suggests that harnessing elephant TP53 properties could lead to new cancer therapies. The field of comparative oncology, which studies cancer across different species, is crucial for these discoveries. While purebred dogs share many genes and tumor types with humans, offering research potential, elephants present a unique case of cancer resistance due to their multiple TP53 copies. Scientists are exploring how to translate these evolutionary findings into practical treatments for patients.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG1nHHsTVzbhwdxePhlAGL2eL1N0JANtlZ29gwDtywie2cWtAehkCG99cElUg4in9JgABp39KjZSIQH8oZdWqMNwyTmImndX6ZTpBVKOiCvEU6Li63V5qM_8NvV8re-2GJkSlhaIQtleSK4BR3PJMTt4V7jvE6U1X-i7aBGMHV7yXr_D8jLufzxncL-yJQBa6z5cAyko7Vjrjhjm17I5b6R1RYVAMoK0UmnR9pgOBE9A16uKHRN7Rf3oSGHzC0-RBYkemCHoYK9hPUrQbo-GbG2OZOb0lb3ywSMeF8v189w_jjYr7dHJBIk7dY5x-5_4jOk"
#   },
#   {
#     "title": "Elephant genes could hold the key to avoiding cancers",
#     "abstract": "Scientists have discovered that elephants possess 20 copies of the p53 gene, known as the 'guardian of the genome,' which is significantly more than the single copy found in other mammals. This genetic duplication is linked to elephants' remarkable resistance to cancer. Despite their large size and human-comparable lifespan, elephants have an estimated cancer mortality rate of less than 5%, in contrast to up to 25% in humans. The research, utilizing bioinformatic modeling, identified how these multiple p53 molecules in elephants are activated for heightened sensitivity and response against carcinogenic conditions. These findings have implications for developing new cancer treatments in humans. The interaction between p53 and MDM2 is crucial for cell division and repair; elephants, with their numerous p53 variants, exhibit a wider range of molecular anti-cancer interactions than humans. This research provides new insights into how p53 functions in tumor suppression and could pave the way for therapies that enhance p53 activity in humans.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEpKyww04vX5G_5n09Rehzd5Rn9HmRHzkUemDHw47Rehsuq6zbXDgT52i7joFuapgfx6EfwRilzbTUPA8mSIZoROwbkIpMmHOuPiAaQody6_udOJUlHV7jl3A9IbZJXVmSt59x5iJ2HcvjCb4-iFSoqnqtXohLXPK-1PE7NwqjnrqTgBZIL7_yPDTylaFqf"
#   },
#   {
#     "title": "Why Elephants Rarely Get Cancer",
#     "abstract": "A study led by the Huntsman Cancer Institute at the University of Utah suggests that elephants' rarity of cancer is due to having multiple copies of a gene that inhibits cancer, specifically p53. Elephants possess at least 40 copies of genes that code for p53, a tumor suppressor, compared to humans who have only two. The study also indicates that elephants may have a more efficient mechanism for eliminating damaged cells that could become cancerous. This enhanced cellular activity is significantly higher in elephant cells than in human cells or cells from patients with Li-Fraumeni Syndrome, who have a very high cancer risk due to having only one working copy of p53. These findings suggest that the abundance of p53 could be the reason for elephants' superior cancer resistance and may inspire new cancer treatment strategies for humans. The research involved analyzing the African elephant genome and collaborating with zoos to study elephant blood samples. The implications of this research align with the concept of comparative oncology, learning from other species to improve human health.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGGRA-CvQrN_fJ5_Tr6R71BWUTK9flBrlOK0ECMysmiFJdvgCVJoeceaMGuZN9prKdey8kYW66ZwNxaR-mhGBdWKc3LZAQSuoEZZgsP_OuKCOveOUTwV5KAnxssL-DL9CHG5Nu3VF_B86HLb8R7InhV2jWsUXPTUExxDrf1IH6M2hkOSNOtK2HDsITsRZA="
#   },
#   {
#     "title": "Walking Through Elephant Cancer Resistance: What it can teach us about elephants, genetics and disease defenses",
#     "abstract": "This paper explores the phenomenon of 'Peto's Paradox,' where larger animals with more cells do not necessarily have a higher cancer rate. Elephants, despite their size, exhibit remarkable cancer resistance. Scientists attribute this to having extra copies of tumor suppressor genes, specifically TP53 and LIF. While elephants have significant immunity to cancer, they are not entirely immune, with certain types of cancer, such as reproductive tract neoplasia, being more susceptible in Asian elephants. The paper references the role of p53 in protecting mammals against cancer and efforts to develop drugs based on this protein. It also touches upon the evolutionary history of TP53 copies in elephants and related species, and the identification of different transcripts for LIF. The research also notes that elephant cells demonstrate greater apoptosis (cell death) than healthy human cells when exposed to DNA damage, further contributing to their cancer defense.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH2gOx_LgyRVboXKCnG6EwWtYStUc3HWi5o33RaxnlYkGvwdiPXyUxNx5djdKv6eWVO5gTBiDe9h2Cbu7SapPrYmJPXWyCzBYa8CEEujE6clgu6smys4b7-UyKeCFdVhcHEYI4nBkBqNAwIHSLYtOH7MUTQTLa9MupT8YlaYnmdPs91K8WpqCBr7vXHVqa_qcdM0OVyh4PTjUtQ0_gnRIhf0BUfNcOsWG4NgubsMhCrnf0bv4inVKyt3vvX7XSCrvwAWNqIsYSo7Gj0mcqiPD4weT4d-ijR5mFcSPam"
#   },
#   {
#     "title": "Illuminating Cancer Resistance in Elephants",
#     "abstract": "A study reveals that elephants possess at least 20 copies of the tumor suppressor gene TP53. Furthermore, their cells tend to undergo apoptosis (programmed cell death) rather than DNA repair when exposed to DNA-damaging agents. These findings contribute to understanding elephants' longevity and low cancer incidence, shedding light on natural cancer suppression mechanisms.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEXEyctwMv2lKO-Mw9BQ_2XvqPB7zwcoD_41Vp8RVqms9hbgKYq2VAbCjJqHHhirOpNl2XhLc_NW0V35GjIbJ6Oa-PXyiIeKeyApI4fOSWm8iaKkMjnW22Ue3E_6ISKIf4GBwQ_"
#   },
#   {
#     "title": "Elephant genes could hold the key to avoiding cancers",
#     "abstract": "Elephants exhibit a cancer mortality rate of less than 5%, significantly lower than the 25% seen in humans, despite their large size and comparable lifespan. This enhanced resistance is attributed to their possession of 20 copies of the p53 gene, often referred to as the 'guardian of the genome,' whereas other mammals, including humans, have only one. Researchers have utilized bioinformatic modeling to understand how these multiple p53 molecules in elephants are activated, leading to increased sensitivity and responsiveness against carcinogenic conditions, which holds potential for human cancer treatments. The intricate molecular interactions of the p53 protein, crucial for preventing cancer, are being investigated. The study highlights the complexity of elephant genetics and physiology, emphasizing the importance of conservation and detailed study of these animals.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHK_pzPTLUVtbW9rwG3_WFFJr_Bl8QgEKXPb6vH3tLT8emmYMsWp3puz3nAMnvao--VIR9iF8JNMJlf8IlHiJsBzhoByN8vInhKQIckBwDmc0fd51FUcjq00zLnFW7Rfoz1rFMn1QeHFo3jrhuPa3m1n9xu5h3bq0FQz6CHaZsumBJaZ3Q7lR-gcB_nYZLo4dw="
#   },
#   {
#     "title": "What can elephants teach us about cancer?",
#     "abstract": "Elephants possess an extraordinary resistance to cancer, with an estimated mortality rate of around 1 in 20, compared to about 1 in 4 for humans. This phenomenon, known as Peto's paradox, challenges the notion that larger animals with more cells should have a higher cancer risk. Elephants have approximately 20 copies of the TP53 gene (40 versions) in each cell, a gene critical for cancer protection. Unlike humans, who have only one copy of TP53, elephants' multiple copies have evolved distinct ways of interacting with other proteins, making it difficult for cancers to evade detection. Research suggests that elephant TP53 acts as a self-destruct trigger for cells with DNA damage, even when introduced into human cancer cells in lab studies. Scientists are exploring how to mimic or enhance the function of TP53 in human cells as a potential cancer medicine strategy.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEpGyCcVqYUnbdy7oO1RfkJayebT-4PgyPZEgQ43gH5DDvZG97eB5fvLJUCDdMnPxayLBdfeEUdmolVubzqf62se70oKpKy3_A3Bzi_0qI3DEtpFTuTQO8YxrwaY9yOZLlv6SyRn-4vHkyHIZop8n4qg3PuV_H_SZq4ueR3fS0JL_I="
#   },
#   {
#     "title": "This Gene Stops Elephants From Getting Cancer: Can It Help Human Cancer Research?",
#     "abstract": "Elephants, along with other large and long-lived animals like whales, exhibit a lower incidence of cancer than expected, a puzzle known as Peto's Paradox. Studies have revealed that elephants possess around 19 extra copies of the TP53 gene, a potent cancer-stopping gene that detects DNA damage and initiates cell death in potentially cancerous cells. This genetic advantage likely contributes to their low cancer rates. Recent research has expanded this investigation to nearly 300 species, indicating that many species have evolved unique cancer resistance strategies. While larger body mass showed a slight increase in cancer risk, other factors like longer gestation periods appear to lower it. For human cancer research, understanding how elephants and other species enhance their cancer defenses could lead to new treatments that bolster human cell resilience and reduce cancer incidence or slow its progression.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHNbEgTcUU4UxTGAjwk-Y8mXi7L8u55y1wH43-N4HTRO_qER5V7sEoGzIpmFspIBF_0gfY55bY5ScUSE7-HZqJx4gsQc2ad-yYSGDsmYu14Yi4h-nwng-qEbL_fSuQGlHrWr6Sbzjq6wGpmjs40qee6hDQl3Jvf3clY1VIowlR9KDgpkRLJG5b2bpPaQnnD9mxAdAhfkCuhSgKofu_W5es0fVhfmwqP8Q=="
#   },
#   {
#     "title": "How elephants beat cancer",
#     "abstract": "Elephants have significantly reduced their risk of cancer by duplicating the essential gene TP53. This phenomenon, known as Peto's Paradox, highlights that large animals with long lifespans do not necessarily have higher cancer rates. While humans have one copy of TP53, which is crucial for cancer protection and often mutated in adult cancers, elephants have 20 copies. Some of these copies are slightly different from the human version. Elephant cells exhibit enhanced sensitivity to DNA damage and are more prone to apoptosis (programmed cell death) than cells from other mammals. Research suggests that these duplicated TP53 genes, particularly retrogenes, are responsible for this enhanced apoptosis response. Introducing these retrogenes into mouse cells also increased their sensitivity to DNA damage, indicating their role in cancer prevention.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG3nIY9fIS3bMuGC8ZCqxi5h56f5XTqlTNXf9MrvFj4XyQCz0jg1pl4Y9u0ZVtwV-Fx7qX1AL7XRXeBzDTZrl3xUgJHXJA7REO8xb4zbJR7GS5KLHi8wdky7z3rIRLBVHpNghEDTpMAODU4Mi8="
#   },
#   {
#     "title": "Surprising ways animals and plants protect human health",
#     "abstract": "Elephants, despite their large size, have a low incidence of cancer due to a gene that prompts cells with DNA damage to self-destruct. Scientists are studying this natural defense mechanism for insights into human cancer research. The article also mentions other examples of nature's contributions to human health, such as frogs deterring malaria, bats reducing pesticide use, wolves preventing car accidents, and vultures protecting against rabies. It touches upon the use of yew trees in chemotherapy drugs and the study of invertebrates for potential disease-fixing mechanisms. The focus on elephants highlights how understanding animal biology can lead to advancements in human medicine.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGsww9CA8i05YZue44SKlTxe2jN1nmaRkdFGuvFcxxtdqh7SW4w7eZ2qvz_h2puZ8FPZxlhNd42Eac4-oFiXD5S4ohPuRWKju0z0M9uggDFKtUuOxbh82y-N7QrtbWMlh3PRTaYVXPCQ5goyeIOploUvmg0Tz4mzVmVtIw4jylnMJV_1OMwaXh2OZHlWXiM_LrWzR922lZ0u3xnu5MB8Uq2ugpF558="
#   },
#   {
#     "title": "How elephants evolved to beat cancer, and how we could too",
#     "abstract": "Elephants exhibit an unusually low rate of cancer, defying Peto's Paradox, which suggests larger animals with more cells should have a higher cancer risk. This paradox is explained by elephants possessing approximately 20 distinct copies of the tumor-suppressing gene p53. Unlike humans, who have only one copy of p53, elephants' multiple copies have evolved unique mechanisms for cancer suppression. One hypothesis suggests that the proliferation of p53 genes in elephants may primarily serve to protect their sperm from DNA damage due to high body temperatures, with cancer protection being a secondary benefit. Research in 2022 investigated how the variety of p53 genes in elephants suppresses cancer, offering potential insights for developing new cancer therapies for humans.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHpOF9M51tcsl6jITv05xcBlvQoZPEYZ4Hg6PqHbtab4XvYy7Ch4O9Jlp_VGlSeL5ClvfiRaLZQHxnkcCY3ZwR-iGTn7VfJ8xsXhsnNYesnaUXU8m9u2ODZ72NNfI9Rs4UILXBqbfrt49LOYWLfX39V6A8qXKAeU_ysxHErDf9Nx-Jcup-JRxpdpDcjA0Pr7A=="
#   },
#   {
#     "title": "Resistance to cancer in elephants – inspiration for human medicine?",
#     "abstract": "Elephants have a remarkably low incidence of cancer, with only about one in twenty dying from the disease, contrasting with the one in four human mortality rate. This phenomenon, known as Peto's paradox, has led scientists to investigate the genetic mechanisms behind elephant cancer resistance. Research indicates that elephants possess multiple copies of the p53 gene, crucial for controlling cell division and preventing tumor formation. While humans have two copies of p53, elephants have many more, with some research suggesting up to 40 copies. This genetic advantage appears to be a key factor in their enhanced cancer defense. Scientists are exploring whether a similar approach, potentially involving targeting p53 degradation pathways or increasing p53 levels, could be beneficial for human cancer therapies, although challenges related to treatment accuracy and side effects remain.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGTZoFEL4Jv9lPIkZWmHdAJtVF6VRkE2_HEi40R-zSWrSW7q1Bs-wk91oHiWbloBnlmrVvnJua1226694wOjbOue4_Zi1zTOTq317rxMS_Ybz636H4ra4i842erBhbvAcDQsLIf5_BlNGWDIgfm_dMP0ign5feKdnrAPpKxr6JL0I75Il1LciyR6JBnWCy4bhgB3TgR9r_eVJqDBA4YDuBpAC4r0SA0KojB"
#   }
# ]
# ```
# Warning: there are non-text parts in the response: ['function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > ### Elephant Cancer Resistance and the Role of TP53
#
# A significant body of research highlights the remarkable cancer resistance observed in elephants, a phenomenon often framed within the context of Peto's Paradox. This paradox questions why larger, longer-lived animals do not invariably exhibit higher cancer rates, given their increased number of cells and prolonged exposure to potential carcinogens. The primary explanation emerging from these studies is the elephants' genetic makeup, specifically their possession of multiple copies of the **TP53 gene**.
#
# Unlike humans, who have two copies of TP53, elephants possess a significantly higher number, estimated to be between 20 and 40 copies. This gene is crucial for cancer protection, acting as a tumor suppressor by detecting DNA damage and initiating cellular responses, including apoptosis (programmed cell death). The duplication of TP53 in elephants appears to confer enhanced cellular sensitivity to DNA damage, leading to a more robust self-destruction mechanism that prevents the proliferation of potentially cancerous cells. This enhanced apoptotic response has been observed in elephant cells when exposed to DNA-damaging agents, distinguishing them from human cells and even cells from individuals with Li-Fraumeni Syndrome (who have a deficiency in TP53 function). The evolutionary advantage of these multiple TP53 copies is thought to contribute to elephants' low cancer mortality rate, estimated to be less than 5%, significantly lower than the human rate of up to 25%.
#
# ### Comparative Oncology and Potential for Human Therapies
#
# The study of elephant cancer resistance falls under the purview of **comparative oncology**, an interdisciplinary field that leverages insights from cancer across different species to advance human medicine. The unique genetic architecture of elephants, particularly their amplified TP53 system, offers a compelling model for understanding natural cancer suppression. Researchers have demonstrated that elephant TP53 genes, when introduced into human cancer cells in laboratory settings, can effectively induce self-destruction. This suggests that harnessing the properties of elephant TP53 could form the basis of novel therapeutic strategies for human cancers. The intricate molecular interactions of the elephant TP53 protein and its variants with other cellular components are being actively investigated to understand how to best translate these findings into practical applications.
#
# ### Research Gaps and Future Directions
#
# While the role of multiple TP53 copies is a central theme, several research avenues warrant further exploration. Firstly, a deeper understanding of the **specific functions and interactions of each elephant TP53 variant** is needed. It is not merely the number of copies but how these genes and their associated proteins uniquely contribute to enhanced DNA damage response and apoptosis that holds the key to translating these findings. Secondly, while elephants exhibit remarkable resistance, they are not entirely immune to cancer, with certain types, such as reproductive tract neoplasia in Asian elephants, being noted. Further research into these **specific vulnerabilities** could reveal additional layers of elephant cancer defense or highlight instances where their mechanisms may be overcome. Finally, translating these findings into effective and safe human cancer therapies presents a significant challenge. Investigating methods to **accurately and safely enhance TP53 activity or mimic its protective functions in human cells** without causing detrimental side effects remains a critical area for future research.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# None

# %%
#Making use of model memory
response = await run_session(lit_review_runner, "Based on the last conversation, what other animals exhibit similar traits? Find research gaps", 'conversation-01')
print(response)
# Out:
# ### Session: conversation-01
#
# User > Based on the last conversation, what other animals exhibit similar traits? Find research gaps
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > Here are some animals that exhibit cancer-resistant traits similar to elephants, along with identified research gaps:
#
# **Animals with Similar Cancer Resistance Traits:**
#
# *   **Bowhead Whales:** These large, long-lived marine mammals have shown efficient DNA repair mechanisms and multiple copies of tumor-suppressor genes like TP53, contributing to their cancer resistance and longevity.
# *   **Naked Mole Rats and Blind Mole Rats:** These rodents possess extraordinary cancer resistance due to unique mechanisms, including specific hyaluronic acid in their extracellular matrix and redundant tumor-suppressing genes.
# *   **Bats:** Certain bat species exhibit cancer resistance, potentially linked to their ability to counteract oxidative stress during flight, leading to mitochondrial alterations that may suppress cancer cells.
# *   **Other Diverse Species:** A study identified over 90 species with high cancer resistance, including the Rodrigues Fruit Bat, Common Dolphin, Common Porpoise, Black-Footed Penguin, and Egyptian-Snouted Cobra, indicating that cancer resistance is not limited to large animals.
#
# **Research Gaps:**
#
# 1.  **Comparative Genomics:** A deeper understanding of the genetic basis of cancer resistance across a broader range of species is needed. Identifying novel cancer-suppressing genes and pathways beyond TP53 is crucial.
# 2.  **DNA Repair vs. Apoptosis Mechanisms:** Further investigation into the balance between DNA repair and apoptosis as cancer defense mechanisms in different species (e.g., whales prioritizing repair, elephants prioritizing apoptosis) is required to inform human therapeutic strategies.
# 3.  **Role of the Tumor Microenvironment:** The contribution of the tumor microenvironment, such as the extracellular matrix in naked mole rats, to cancer resistance in other species needs more exploration.
# 4.  **Translational Research for Human Therapies:** Significant challenges remain in translating these findings into safe and effective human cancer therapies. Research is needed on how to safely enhance TP53 function, replicate the effects of specific molecules like hyaluronic acid, or bolster DNA repair pathways in humans.
# 5.  **Understanding Peto's Paradox Across Species:** More detailed studies are needed on how Peto's Paradox applies to smaller, yet highly cancer-resistant, species to develop a more comprehensive understanding of cancer suppression across diverse life forms.
# 🔑 Auto-saving Orchestrator turn to MemoryService...
# Model: > ```json
# [
#   {
#     "title": "Peto's Paradox: Evolution's Prescription for Cancer Prevention",
#     "abstract": "Peto's Paradox highlights the inverse relationship between body size/lifespan and cancer rates, suggesting that larger, longer-lived animals have evolved superior cancer suppression mechanisms compared to humans. Research into these mechanisms, present in species like whales and elephants, holds promise for developing novel cancer prevention strategies. The study of these evolutionary adaptations could revolutionize cancer prevention by harnessing nature's solutions to suppress cancer, potentially eradicating it as a public health threat. The focus is on understanding how these large animals suppress cancer to inform human cancer prevention.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG7TWgqIMshjTUDyjglmPKoI2OSJUC-Frcht4y1MP4juv1JK92bC99JtQBkgDNufIIHr6B2rhkZN1bgnKdqtXVAlqCswkZ1z8vuvevI_PQ8XMTValimj4E22Z5cDfAo9CfPi8nm2wvWYUHnYIs="
#   },
#   {
#     "title": "Immune to Cancer: Naked Mole Rats Reveal Their Secret",
#     "abstract": "Naked mole rats exhibit remarkable cancer resistance, possibly due to a unique substance called hyaluronan found between their tissues. This high-molecular-mass hyaluronan (HMW-HA) is a component of the extracellular matrix that acts as a signal to control cell growth and prevents tumor development by inhibiting cell overcrowding. Understanding this mechanism could lead to novel cancer-prevention techniques for humans, as HMW-HA may play a crucial role in their resistance to cancer.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGe5l9MTidV1woejuXJSD7PokpC9ldeDgjRLqdW-xBT9z7lIUOigWAwywDUoB7QuvWkGqif3AWcK-5dovdhs6a6ojEytkWm54KkNcC1WFTyBq_rKRl4R4uXJCjg94T2e3fgSiMVryG-7TuGa-NaLHOtcaeEnHk8mPkihkhA9v-TdkWxbg=="
#   },
#   {
#     "title": "Naked mole rat's secret to staying cancer free",
#     "abstract": "Scientists have discovered that naked mole rats have a unique mechanism for staying cancer-free: a super sugar called high-molecular-mass Hyaluronan (HMM-HA). When secreted by their cells, HMM-HA prevents cells from overcrowding and forming tumors. This molecule plays a crucial role in their cancer resistance and may offer new avenues for cancer prevention and life extension in humans. The researchers believe HMM-HA may have evolved to provide elasticity to their skin for life in underground tunnels, with cancer prevention as a beneficial side effect.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF6Ys8FhfFrZaLfXR719QkyWHOdQtik3TxDALF3-3wk2y9uOOT_Jw1SCxkU_napmxKPBzPL38gJUiYVbmtdbZEkxBD-yGEBpz_hOXl9hsgB_sYQX3jNAYOvPIW8Hbs0axh-8F_YF9cr06l8av99eQVYQpsf9Au71oQy"
#   },
#   {
#     "title": "Beyond Peto's Paradox: Expanding the Study of Cancer Resistance Across Species",
#     "abstract": "Peto's paradox, which notes the lower-than-expected cancer rates in larger or longer-lived species, is central to understanding cancer resistance. This perspective emphasizes the need to investigate species that, despite traits theoretically increasing cancer risk, exhibit unexpected resistance. The research suggests expanding the focus beyond size and longevity to include species with traits beyond these factors that still show cancer resistance. Transmissible cancers are also highlighted as a means to understand how metastatic processes might be naturally suppressed. This research aims to identify anti-cancer adaptations throughout evolution in the animal kingdom.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG3wealBdyVL83CPIptSRJ1qfdLrl4QHqimgmXVza1u9mXAeZ6G6X0cxoUWwL28Wzi8lQotIn3lnb46FE_cRbaOF_yD7dx3KDFWOA=="
#   },
#   {
#     "title": "High molecular weight hyaluronic acid mediates the cancer resistance of the naked mole-rat",
#     "abstract": "Naked mole-rat fibroblasts secrete extremely high molecular weight hyaluronan (HA), which is significantly larger than HA found in humans or mice. This HMW-HA accumulates in their tissues due to decreased activity of HA-degrading enzymes and unique HAS2 enzyme activity. Naked mole-rat cells are also more sensitive to HA signaling. These factors contribute to their enhanced cancer resistance by promoting early contact inhibition and suppressing oncogenic transformation, possibly stemming from adaptations for their subterranean lifestyle.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEg3hQxyxe_OKxlIXDXx4BX3Y_Qa7_6Ip2HoNaGfseqM13lwZzOYYahWPryGTrJA3bPrtt_d45N_kRqEbeBfOE72LlvKI72PJo7AHFA9fCCzw6t_YS743yB5xhe9-H9S1AbrH_BG6ZESEvtYiM="
#   },
#   {
#     "title": "Cancer resistance, high molecular weight hyaluronic acid, and longevity",
#     "abstract": "The naked mole rat, a long-lived rodent, is essentially cancer-free due to the abundant production of high molecular weight hyaluronic acid (HMW-HA). This HMW-HA accumulates in the extracellular matrix and stimulates an intracellular pathway that induces p16ink4a expression, suppressing oncogenic transformation. This mechanism, combined with their longevity, highlights the intriguing link between cancer resistance and extended lifespan in this species.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEMXw5sobEwUXisJn5zn2GRNZeQv01pMQZQ3l2rZrccd6doX355cgLSGfwDwCfQUT9PwNMhU4qg9jxIt1N8cegOWSOqVyypl5sRaIi-oKgzVmnKMYSab5AEwX95jUJbuG9nMGWSwaFnBnPsbMM="
#   },
#   {
#     "title": "The whale that lives forever: Cancer prevention mechanisms in the bowhead whale",
#     "abstract": "Bowhead whales, known for their exceptional longevity and cancer-free lives, appear to have evolved advanced tumor suppressor mechanisms that differ from elephants. While elephants have multiple TP53 genes promoting apoptosis, bowhead whales exhibit lower p53 activity but possess highly efficient DNA repair mechanisms. This 'conservative' strategy of repairing damaged cells, rather than eliminating them, may be crucial for their long, cancer-free lifespan and could offer insights for human cancer prevention.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEpsgDXbKBHycnbF1Ul0feG6rAOghfX0TzfuYlNuI8dnfIaDEJmmMMIrtvePix24noBf5k5xHlC9iDeoGx9tdILq2AP4E33WUFXQ-L2kGJsnNRevzhUuzhDDpXZij9fIPRMr4GXMcfUy93QYaiwFHEmulgOmQquzHgCklWdaCJ0hclgKPjZRfkPKogoFKeDanvTMlo6sL9x6XUBuMBFYLBaWLfz2g=="
#   },
#   {
#     "title": "DNA repair and anti-cancer mechanisms in the longest-living mammal: the bowhead whale",
#     "abstract": "Bowhead whale cells exhibit remarkable cancer resistance, relying on highly accurate and efficient DNA double-strand break (DSB) repair, mediated by proteins like CIRBP and RPA2. This strategy, which prioritizes repair over cell elimination (apoptosis or senescence), appears critical for their long, cancer-free lifespan. Unlike elephants, which have multiple TP53 genes and enhanced apoptosis, bowhead whales show lower p53 activity. Their approach to maintaining genomic integrity through superior DNA repair offers a distinct model for cancer resistance and longevity.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFYC3qG-R40oGpFpcXomc5ZqniogBTdiVMLr2mxGJI6kSro2Mqu2EFzn5aeu16ro2V3EWcb_tE8zsXefYgAllB4YEuqIVmnkVig8vs7CAcwkfK1nsAkBJX4Q-wTqvOj20jRVnsSoW-FiMceMLCTp0n5cWFaey3rkXrZEunHTCniQQ=="
#   },
#   {
#     "title": "Anticancer mechanisms in the Bat",
#     "abstract": "Bats exhibit various anticancer mechanisms, potentially contributing to their cancer resistance. Some species minimize or repair oxidative stress effects via TP53 and BRCA2. Others utilize drug efflux pumps like ABCB1 to resist carcinogenic chemicals. Upregulation of tumor-suppressive microRNAs, stable genomes maintained by specific proteins (DZIP3, PLK4), and DNA damage-induced growth arrest mediated by FBXO31 are also implicated. Reduced GH-IGF1 signaling may also play a role in cancer resistance in certain bat species.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGZ0KNQtJCvW8D2CuByhq9LsJQSzpw4_657jVWU6LLPaVxdH1Xoch3O-ShqpTHRi2Q3yUVb3YK_HJTnt10zJBsQivuRwe13W6etO02G9fm3Cr96MQPOlPboRvfLoqLptTHJ7_A-b3xJc14TF-88E6Bq51vpxGxdzhalDUv2PXxWnjxZKcrNiMX3oC0DLaeoLyMdZksipoDlxbqNo5sHy7nBAAglwIwJa3G2ADiTeWKQPhmcv00stTajwK8cLFjg7pO1HF4="
#   },
#   {
#     "title": "Experimental evidence for cancer resistance in a bat species",
#     "abstract": "This study provides direct experimental evidence for cancer resistance in bats, specifically the big-footed bat (Myotis pilosus). Their resistance is linked to the downregulation of three genes associated with cancer: HIF1A, COPS5, and RPS3. The loss of a specific enhancer region in the COPS5 gene may be responsible for this downregulation. These findings shed light on natural cancer resistance mechanisms in mammals and suggest that bats, particularly long-lived species, possess molecular drivers for cancer resistance.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF5x1lOHggThjdNxHjEsQRtNo6oA_Ys5b2YzslPzEzP5MRZYV2vXzcDqQUdtzCQMERURsoQE-0EiZh3BwGTZC3FsyOus5XA5fA-50US8w3qSpNjxnq8G6wXyFQPePTExiqgVZ7XEDvuTPozTyA2"
#   },
#   {
#     "title": "Limited cell-autonomous anticancer mechanisms in long-lived bats",
#     "abstract": "While long-lived bats show cancer resistance, this study suggests their mechanisms may not be entirely cell-autonomous. Although some bat species exhibit telomerase activity and require fewer oncogenic hits for malignant transformation, they may rely on enhanced p53 signaling and improved immunosurveillance for cancer prevention. The study also notes a genomic duplication of TP53 in some bat species, similar to elephants, suggesting a potential evolutionary strategy for cancer resistance.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGRnYz-bjKaWKoD6I4273dVig2sj0kkXpa9FmtQA2IdBEMcrZG-L-8B8D70GqmloxaiC6fuViCzVnOmFadQ6Vk3kNPl6AjF3XqWVG8EG-v_l7Hs6ZfSGH9GBGbAhtdugMEsJ_FgMSORVsiAk5zq"
#   },
#   {
#     "title": "Comparative oncology: overcoming human cancer through companion animal studies",
#     "abstract": "Comparative oncology leverages studies of companion animals, particularly dogs, to understand cancer and develop new therapies. Dogs share significant genetic similarities with humans, spontaneously develop similar cancers, and have comparable microbiomes and immune systems. This makes them valuable models for evaluating biomarkers and anticancer targets before clinical translation. Research on canine cancers is growing, providing insights into genetic and epigenetic similarities that can lead to new molecular targets for anticancer therapeutics.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHLd0JdIHW9fJyR0sJ5E31zd-wZ6NtaKHHOuEWo9AxK-j6kzXBzznUhU5XyggyLCFFx1apFVGvI6xwIZi01tepL3gXXkuQynHx5Pfn8G1PTu_AfpfdqKrYaBPiLRatlHCF0t_UkUzlXoguyt4qg"
#   },
#   {
#     "title": "Mass extinctions, biodiversity and mitochondrial function: are bats 'special' as reservoirs for emerging viruses?",
#     "abstract": "Efficient mechanisms for countering oxidative damage in bats may lead to a lower rate of tumorigenesis. Their high metabolic rate, associated with flight, could generate more oxidative byproducts, but bats possess mechanisms to resist oxidative damage, which is a known driver of tumorigenesis. While not definitively proven, this efficient mitochondrial function and oxidative damage resistance could contribute to cancer resistance in bats.",
#     "url": "https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFtWMSwlFAXgRkQn7kYoULKo5TGdtw13eQsv1xO-47GVy7UhQPBuV3zRRmKvAMdFj6gPVAFCqmR8YPJF6VVfxrCiZDwUuUyMzSA6cog1dGr_dlHAXmm6MwEvO_2A1MHWi1mExjjL3a12SIg9m4="
#   }
# ]
# ```
# Warning: there are non-text parts in the response: ['function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > ### Comparative Cancer Resistance Across Species
#
# Research into cancer resistance in animals, particularly in the context of **Peto's Paradox**, reveals a diverse array of evolutionary strategies employed by species to mitigate cancer risk, often defying expectations based on body size or lifespan. These mechanisms offer valuable insights into fundamental biological processes that could inform human cancer prevention and treatment.
#
# *   **Whales (Bowhead Whales):** These exceptionally long-lived marine mammals exhibit a remarkable capacity for **DNA repair**. Unlike species that primarily eliminate damaged cells (apoptosis), bowhead whales appear to prioritize accurate repair of DNA double-strand breaks (DSBs) through efficient mechanisms involving proteins like CIRBP and RPA2. While they do possess multiple copies of TP53, their lower p53 activity suggests a greater reliance on this repair-centric strategy for maintaining genomic integrity and preventing cancer over their extended lifespans.
#
# *   **Naked Mole Rats and Blind Mole Rats:** These rodents are models of cancer resistance, attributed to unique adaptations. Naked mole rats, in particular, produce abundant **high-molecular-weight hyaluronan (HMW-HA)**, a component of their extracellular matrix. This HMW-HA promotes early contact inhibition, suppresses oncogenic transformation, and stimulates pathways like p16ink4a expression. Their resistance may also stem from **redundant tumor-suppressing genes** and a reduced activity of HA-degrading enzymes, leading to the accumulation of HMW-HA.
#
# *   **Bats:** The cancer resistance observed in various bat species is linked to several factors. Some minimize or repair **oxidative stress**, a known driver of tumorigenesis, through mechanisms involving TP53 and BRCA2. Others utilize **drug efflux pumps** to resist carcinogens or upregulate **tumor-suppressive microRNAs**. Bats also demonstrate stable genomes maintained by specific proteins and DNA damage-induced growth arrest. Certain species may have undergone genomic duplication of TP53, similar to elephants, suggesting convergent evolution for cancer resistance.
#
# *   **Other Cancer-Resistant Species:** Beyond these well-studied examples, a broad survey identified over 90 species exhibiting high cancer resistance, including the **Rodrigues Fruit Bat, Common Dolphin, Common Porpoise, Black-Footed Penguin, and Egyptian-Snouted Cobra**. This finding highlights that cancer resistance mechanisms are widespread across the animal kingdom and not confined to large or long-lived species.
#
# ### Key Research Gaps in Comparative Cancer Resistance
#
# Despite advancements in identifying cancer-resistant animals and their associated mechanisms, several critical research gaps persist:
#
# 1.  **Genomic and Molecular Underpinnings:** While TP53 and HMW-HA are implicated, a comprehensive understanding of the **genetic and molecular basis of cancer resistance across a wider diversity of species** is lacking. Identifying novel cancer-suppressing genes, regulatory pathways, and protein interactions beyond the currently known mechanisms is essential. This includes further exploration of species-specific adaptations and potential convergent evolution.
#
# 2.  **Mechanisms of DNA Integrity Maintenance:** The distinct strategies employed for maintaining genomic stability—namely, **DNA repair versus apoptosis**—warrant deeper investigation. Understanding the evolutionary trade-offs and specific molecular players involved in prioritizing repair (as seen in whales) versus cell elimination (as seen in elephants) could provide critical insights for enhancing human cancer defense.
#
# 3.  **Role of the Tumor Microenvironment and Extracellular Matrix:** The role of the tumor microenvironment, particularly the extracellular matrix and its components like hyaluronic acid, in suppressing tumorigenesis is an underexplored area beyond naked mole rats. Further research is needed to ascertain if similar ECM-based resistance mechanisms exist in other cancer-resistant species and how they function.
#
# 4.  **Translational Applications for Human Therapies:** A significant gap exists in translating these natural resistance mechanisms into effective human cancer therapies. Challenges remain in developing **safe and targeted interventions** that can safely activate or mimic these pathways in humans, such as enhancing TP53 function, replicating the effects of HMW-HA, or improving DNA repair efficiency without adverse side effects.
#
# 5.  **Peto's Paradox in Diverse Contexts:** While Peto's Paradox primarily focuses on body size and lifespan, its applicability and the underlying mechanisms in smaller, yet highly cancer-resistant, species require further investigation. A broader exploration of **traits beyond size and longevity** that confer cancer resistance is needed to build a more complete evolutionary picture.
# Model: > Here are some animals that exhibit cancer-resistant traits similar to elephants, along with identified research gaps:
#
# **Animals with Similar Cancer Resistance Traits:**
#
# *   **Whales (Bowhead Whales):** Possess highly efficient DNA repair mechanisms and multiple copies of TP53, prioritizing repair over apoptosis for cancer prevention.
# *   **Naked Mole Rats and Blind Mole Rats:** Exhibit remarkable cancer resistance due to unique mechanisms like high-molecular-weight hyaluronan (HMW-HA) in their extracellular matrix, redundant tumor-suppressing genes, and reduced HA-degrading enzyme activity.
# *   **Bats:** Show cancer resistance linked to their ability to counteract oxidative stress, potentially involving TP53, BRCA2, drug efflux pumps, tumor-suppressive microRNAs, and stable genomes. Some species may also have genomic duplications of TP53.
# *   **Other Diverse Species:** A broad study identified over 90 species with high cancer resistance, including the Rodrigues Fruit Bat, Common Dolphin, Common Porpoise, Black-Footed Penguin, and Egyptian-Snouted Cobra.
#
# **Research Gaps:**
#
# 1.  **Genomic and Molecular Underpinnings:** A comprehensive understanding of the genetic and molecular basis of cancer resistance across a wider diversity of species is needed, including the identification of novel cancer-suppressing genes and pathways beyond TP53 and HMW-HA.
# 2.  **Mechanisms of DNA Integrity Maintenance:** Further investigation into the distinct strategies of DNA repair versus apoptosis as cancer defense mechanisms in different species is required to understand evolutionary trade-offs and potential human therapeutic applications.
# 3.  **Role of the Tumor Microenvironment:** The contribution of the tumor microenvironment, particularly the extracellular matrix, to cancer resistance in species beyond naked mole rats needs further exploration.
# 4.  **Translational Applications for Human Therapies:** Significant challenges remain in translating natural resistance mechanisms into safe and effective human cancer therapies, requiring further research into mimicking or enhancing pathways like TP53 function, HMW-HA effects, and DNA repair efficiency.
# 5.  **Peto's Paradox in Diverse Contexts:** A broader exploration of traits beyond body size and lifespan that confer cancer resistance is needed to understand the paradox in various species, including smaller, highly resistant ones.
# None
